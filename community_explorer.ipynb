# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
roi_coords = pd.read_csv('./xGW-GAT/community_networks/roi_coords.csv', header=None)
# inverse the row and column
roi_coords = roi_coords.T
# set the column names
roi_coords.columns = ['name', 'x', 'y', 'z']
# drop the first row
roi_coords = roi_coords.drop([0])
# set index to name
roi_coords = roi_coords.set_index('name')
# convert 3 cols to float
roi_coords = roi_coords.astype(float)

# %%
roi_coords
# Out:
#                                                    x          y          z
# name
# Grey Matter                                 0.887563 -24.198027   5.580567
# atlas.FP r (Frontal Pole Right)            26.155852  52.143184   8.257817
# atlas.FP l (Frontal Pole Left)            -24.723502  52.955969   7.508122
# atlas.IC r (Insular Cortex Right)          37.384687   2.549671  -0.173780
# atlas.IC l (Insular Cortex Left)          -36.394252   1.186796   0.082363
# ...                                              ...        ...        ...
# networks.Language.IFG (R) (54,28,1)        53.616387  28.372439   1.154562
# networks.Language.pSTG (L) (-57,-47,15)   -57.025188 -47.448520  15.004861
# networks.Language.pSTG (R) (59,-42,13)     58.552460 -42.021340  12.848844
# networks.Cerebellar.Anterior (0,-63,-30)    0.235647 -63.497001 -30.303342
# networks.Cerebellar.Posterior (0,-79,-32)   0.403107 -78.940459 -31.589497
#
# [165 rows x 3 columns]

# %%
# plot the coordinates of the ROIs in a 3D space
# %matplotlib widget
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(roi_coords['x'].values, roi_coords['y'].values, roi_coords['z'].values)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
