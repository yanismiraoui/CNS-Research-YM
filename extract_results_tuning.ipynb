# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import re

# %% [markdown]
# # Fully Connected

# %%
# Fully connected without masking
with open('./modified_XGW-GAT/save_results_tuning_fc.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#     MLP_layers GNN_layers num_head  hidden_dim dropout  AvgAcc  StdAcc  \
# 21           4         NA       NA          64      NA   85.44    0.63
# 5            2         NA       NA          64      NA   85.44    0.00
# 28           8         NA       NA          32      NA   85.13    0.32
# 27           8         NA       NA          16      NA   84.81    1.27
# 30           8         NA       NA         128      NA   84.81    0.63
# 22           4         NA       NA         128      NA   84.49    0.32
# 14           3         NA       NA         128      NA   84.49    1.58
# 13           3         NA       NA          64      NA   84.49    0.32
# 12           3         NA       NA          32      NA   84.49    0.32
# 20           4         NA       NA          32      NA   84.49    0.32
# 7            2         NA       NA         256      NA   84.49    0.32
# 6            2         NA       NA         128      NA   84.49    0.95
# 10           3         NA       NA           8      NA   84.18    0.63
# 17           4         NA       NA           4      NA   84.18    1.27
# 29           8         NA       NA          64      NA   84.18    1.27
# 0            2         NA       NA           2      NA   84.18    0.00
# 26           8         NA       NA           8      NA   83.86    0.32
# 16           4         NA       NA           2      NA   83.86    0.32
# 15           3         NA       NA         256      NA   83.86    0.32
# 11           3         NA       NA          16      NA   83.86    0.95
# 4            2         NA       NA          32      NA   83.86    0.95
# 31           8         NA       NA         256      NA   83.86    0.32
# 19           4         NA       NA          16      NA   83.54    1.90
# 1            2         NA       NA           4      NA   83.54    0.00
# 25           8         NA       NA           4      NA   83.54    1.27
# 8            3         NA       NA           2      NA   82.91    1.27
# 23           4         NA       NA         256      NA   82.59    2.85
# 2            2         NA       NA           8      NA   82.59    0.32
# 24           8         NA       NA           2      NA   82.28    0.63
# 3            2         NA       NA          16      NA   82.28    0.00
# 9            3         NA       NA           4      NA   81.33    1.58
# 18           4         NA       NA           8      NA   80.70    0.32
#
#     AvgAUC  StdAUC  MaxAcc  MaxAUC  TreatmentAcc  TreatmentAUC  ScannerAcc  \
# 21   55.50    0.28   86.08   55.78      0.789104      0.601247    0.888889
# 5    54.67    1.48   85.44   56.16      0.792619      0.587427    0.888889
# 28   55.70    1.00   85.44   56.70      0.611599      0.633333    0.677778
# 27   58.98    1.96   86.08   60.95      0.822496      0.517806    0.911111
# 30   55.62    2.88   85.44   58.50      0.789104      0.565366    0.900000
# 22   53.30    0.12   84.81   53.42      0.794376      0.528691    0.911111
# 14   55.65    0.68   86.08   56.33      0.782074      0.581044    0.888889
# 13   52.76    1.02   84.81   53.78      0.794376      0.596465    0.888889
# 12   55.90    0.80   84.81   56.70      0.792619      0.599387    0.888889
# 20   56.27    0.26   84.81   56.53      0.810193      0.538266    0.922222
# 7    55.99    1.69   84.81   57.68      0.778559      0.610810    0.866667
# 6    53.24    0.56   85.44   53.80      0.783831      0.590082    0.900000
# 10   55.59    2.17   84.81   57.76      0.780316      0.591941    0.877778
# 17   55.65    1.87   85.44   57.52      0.782074      0.581044    0.888889
# 29   54.16    2.07   85.44   56.23      0.608084      0.619246    0.711111
# 0    58.05    0.81   84.18   58.86      0.764499      0.590340    0.877778
# 26   53.50    0.33   84.18   53.83      0.731107      0.621954    0.855556
# 16   57.18    2.51   84.18   59.69      0.789104      0.549420    0.911111
# 15   57.05    0.99   84.18   58.04      0.771529      0.558715    0.888889
# 11   55.82    1.30   84.81   57.12      0.796134      0.569622    0.900000
# 4    53.63    0.21   84.81   53.83      0.743409      0.601494    0.866667
# 31   53.88    1.76   84.18   55.64      0.752197      0.614786    0.866667
# 19   54.88    0.78   85.44   55.66      0.785589      0.595132    0.877778
# 1    59.48    1.99   83.54   61.47      0.695958      0.608650    0.833333
# 25   54.54    0.68   84.81   55.22      0.778559      0.578917    0.888889
# 8    56.46    2.68   84.18   59.14      0.722320      0.616634    0.844444
# 23   56.12    0.90   85.44   57.03      0.790861      0.582377    0.911111
# 2    55.02    0.39   82.91   55.41      0.785589      0.611079    0.900000
# 24   56.47    4.20   82.91   60.68      0.775044      0.584763    0.900000
# 3    53.87    2.19   82.28   56.05      0.780316      0.595927    0.877778
# 9    54.13    0.77   82.91   54.90      0.783831      0.594068    0.900000
# 18   58.75    2.44   81.01   61.19      0.776801      0.601773    0.877778
#
#     ScannerAUC
# 21     0.71875
# 5      0.71875
# 28     0.64375
# 27     0.64375
# 30     0.72500
# 22     0.68750
# 14     0.71875
# 13     0.71875
# 12     0.71875
# 20     0.69375
# 7      0.70625
# 6      0.72500
# 10     0.71250
# 17     0.71875
# 29     0.66250
# 0      0.71250
# 26     0.70000
# 16     0.73125
# 15     0.67500
# 11     0.72500
# 4      0.70625
# 31     0.75000
# 19     0.71250
# 1      0.68750
# 25     0.71875
# 8      0.69375
# 23     0.73125
# 2      0.72500
# 24     0.72500
# 3      0.71250
# 9      0.72500
# 18     0.71250

# %%
# Fully connected with one layer masking
with open('./modified_XGW-GAT/save_results_tuning_fc_masking.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#     MLP_layers GNN_layers num_head  hidden_dim dropout  AvgAcc  StdAcc  \
# 0            2         NA       NA           2      NA   85.44    0.00
# 26           8         NA       NA           8      NA   85.44    0.00
# 30           8         NA       NA         128      NA   85.13    0.32
# 5            2         NA       NA          64      NA   85.13    0.32
# 6            2         NA       NA         128      NA   84.81    0.00
# 23           4         NA       NA         256      NA   84.81    0.00
# 22           4         NA       NA         128      NA   84.81    0.00
# 20           4         NA       NA          32      NA   84.81    0.63
# 18           4         NA       NA           8      NA   84.81    0.63
# 14           3         NA       NA         128      NA   84.49    0.95
# 28           8         NA       NA          32      NA   84.49    0.32
# 1            2         NA       NA           4      NA   84.49    0.32
# 31           8         NA       NA         256      NA   84.49    0.32
# 10           3         NA       NA           8      NA   84.49    0.32
# 4            2         NA       NA          32      NA   84.49    0.95
# 3            2         NA       NA          16      NA   84.18    0.63
# 21           4         NA       NA          64      NA   84.18    1.27
# 11           3         NA       NA          16      NA   83.86    0.95
# 19           4         NA       NA          16      NA   83.86    1.58
# 7            2         NA       NA         256      NA   83.86    0.95
# 25           8         NA       NA           4      NA   83.86    0.95
# 22     0.69375
# 20     0.66250
# 18     0.70625
# 14     0.71250
# 28     0.68750
# 1      0.66875
# 31     0.67500
# 10     0.70625
# 4      0.75000
# 3      0.70625
# 21     0.69375
# 11     0.66250
# 19     0.72500
# 7      0.65000
# 25     0.81250
# 12     0.72500
# 13     0.70625
# 17     0.68125
# 29     0.69375
# 27     0.76250
# 15     0.65000
# 2      0.70625
# 8      0.75625
# 16     0.63125
# 9      0.68125
# 24     0.73125

# %% [markdown]
# # GCN / GNN

# %%
# GNN without masking
with open('./modified_XGW-GAT/save_results_tuning_gcn.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#     MLP_layers  GNN_layers  num_head  hidden_dim  dropout  AvgAcc  StdAcc  \
# 8            3           2         2           2      0.5   81.96    2.22
# 7            2           3         4           4      0.5   80.70    3.48
# 3            2           2         4           4      0.5   80.38    0.00
# 9            3           2         2           4      0.5   80.06    0.95
# 11           3           2         4           4      0.5   80.06    0.32
# 14           3           3         4           2      0.5   79.11    0.63
# 6            2           3         4           2      0.5   78.80    4.11
# 15           3           3         4           4      0.5   78.48    2.53
# 2            2           2         4           2      0.5   77.85    0.63
# 12           3           3         2           2      0.5   77.53    2.22
# 13           3           3         2           4      0.5   76.27    0.32
# 10           3           2         4           2      0.5   75.95    1.27
# 5            2           3         2           4      0.5   75.63    2.22
# 1            2           2         2           4      0.5   75.32    0.00
# 4            2           3         2           2      0.5   75.32    0.00
# 0            2           2         2           2      0.5   70.25    7.59
#
#     AvgAUC  StdAUC  MaxAcc  MaxAUC  TreatmentAcc  TreatmentAUC  ScannerAcc  \
# 8    54.86    2.28   84.18   57.13      0.651408      0.561801    0.800000
# 7    58.14    3.39   84.18   61.53      0.779930      0.520094    0.866667
# 3    55.35    0.47   80.38   55.81      0.786972      0.576156    0.855556
# 9    57.33    0.42   81.01   57.74      0.750000      0.525877    0.877778
# 11   54.98    1.24   80.38   56.22      0.757042      0.577954    0.911111
# 14   59.20    0.22   79.75   59.42      0.757042      0.534126    0.888889
# 6    53.06    3.06   82.91   56.12      0.746479      0.535698    0.877778
# 15   56.83    0.08   81.01   56.90      0.779930      0.496188    0.900000
# 2    59.54    2.90   78.48   62.44      0.751761      0.558818    0.866667
# 12   62.14    4.37   79.75   66.51      0.730634      0.573916    0.822222
# 13   58.77    3.60   76.58   62.38      0.632042      0.573981    0.733333
# 10   53.77    0.36   77.22   54.14      0.755282      0.564935    0.822222
# 5    56.35    1.09   77.85   57.44      0.806338      0.567961    0.888889
# 1    57.99    1.65   75.32   59.65      0.762324      0.525371    0.855556
# 4    57.01    3.18   75.32   60.19      0.714789      0.540415    0.800000
# 0    52.98    0.43   77.85   53.41      0.663732      0.577233    0.755556
#
#     ScannerAUC
# 8      0.62500
# 7      0.66250
# 3      0.65625
# 9      0.66875
# 11     0.77500
# 14     0.76250
# 6      0.66875
# 15     0.72500
# 2      0.66250
# 12     0.76875
# 13     0.63125
# 10     0.63750
# 5      0.76250
# 1      0.65625
# 4      0.66875
# 0      0.73125

# %%
# GNN with one layer masking
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_ksupport.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_frobenius.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#     MLP_layers  GNN_layers  num_head  hidden_dim  dropout  AvgAcc  StdAcc  \
# 8            3           2         2           2      0.5   82.59    2.22
# 12           3           3         2           2      0.5   81.96    0.32
# 14           3           3         4           2      0.5   81.96    2.22
# 5            2           3         2           4      0.5   80.70    0.32
# 9            3           2         2           4      0.5   80.70    0.32
# 3            2           2         4           4      0.5   80.38    0.00
# 7            2           3         4           4      0.5   79.75    2.53
# 13           3           3         2           4      0.5   79.43    2.85
# 15           3           3         4           4      0.5   79.43    3.48
# 6            2           3         4           2      0.5   78.80    2.22
# 11           3           2         4           4      0.5   78.48    0.00
# 2            2           2         4           2      0.5   77.85    1.27
# 10           3           2         4           2      0.5   76.58    0.63
# 1            2           2         2           4      0.5   75.95    1.27
# 4            2           3         2           2      0.5   72.47    2.85
# 0            2           2         2           2      0.5   71.84    5.38
#
#     AvgAUC  StdAUC  MaxAcc  MaxAUC  TreatmentAcc  TreatmentAUC  ScannerAcc  \
# 8    55.76    1.90   84.81   57.67      0.772887      0.511846    0.888889
# 12   60.04    1.05   82.28   61.10      0.723592      0.557699    0.855556
# 14   60.85    3.51   84.18   64.37      0.790493      0.530475    0.911111
# 5    56.04    3.15   81.01   59.19      0.781690      0.568973    0.888889
# 9    55.34    2.73   81.01   58.07      0.765845      0.515550    0.888889
# 3    55.64    2.50   80.38   58.13      0.792254      0.579354    0.866667
# 7    60.84    0.01   82.28   60.85      0.776408      0.533900    0.866667
# 13   59.06    3.69   82.28   62.75      0.794014      0.548545    0.877778
# 15   55.70    2.23   82.91   57.93      0.785211      0.535246    0.877778
# 6    53.21    3.21   81.01   56.43      0.723592      0.521839    0.866667
# 11   55.83    0.89   78.48   56.72      0.762324      0.589121    0.900000
# 2    59.96    0.17   79.11   60.14      0.730634      0.561963    0.844444
# 10   54.93    1.88   77.22   56.81      0.755282      0.568919    0.877778
# 1    58.23    2.57   77.22   60.81      0.758803      0.543161    0.855556
# 4    57.64    4.41   75.32   62.05      0.535211      0.567143    0.500000
# 0    55.97    5.47   77.22   61.44      0.788732      0.597144    0.888889
#
#     ScannerAUC
# 8      0.63125
# 12     0.74375
# 14     0.73125
# 5      0.76250
# 9      0.67500
# 3      0.70625
# 7      0.66250
# 13     0.66875
# 15     0.66875
# 6      0.66250
# 11     0.81250
# 2      0.65000
# 10     0.71250
# 1      0.65625
# 4      0.58750
# 0      0.71875

# %% [markdown]
# # GCN WITH VAE comparison hyperparameter tuning

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#     MLP_layers  GNN_layers  num_head  hidden_dim  dropout  AvgAcc  StdAcc  \
# 1            2           2         2           4      0.5   81.73    2.24
# 14           3           3         4           2      0.5   81.73    1.60
# 5            2           3         2           4      0.5   80.77    0.00
# 11           3           2         4           4      0.5   80.77    1.28
# 6            2           3         4           2      0.5   80.13    0.64
# 15           3           3         4           4      0.5   79.81    1.60
# 9            3           2         2           4      0.5   79.49    1.28
# 10           3           2         4           2      0.5   79.49    1.92
# 3            2           2         4           4      0.5   78.85    2.56
# 7            2           3         4           4      0.5   77.24    3.53
# 13           3           3         2           4      0.5   76.92    2.56
# 4            2           3         2           2      0.5   76.28    2.56
# 8            3           2         2           2      0.5   75.00    3.21
# 2            2           2         4           2      0.5   74.04    1.60
# 0            2           2         2           2      0.5   63.78   12.50
# 12           3           3         2           2      0.5   53.85   25.00
#
#     AvgAUC  StdAUC  MaxAcc  MaxAUC  TreatmentAcc  TreatmentAUC  ScannerAcc  \
# 1    58.55    1.68   83.97   60.23      0.786972      0.556234    0.897727
# 14   59.32    1.85   83.33   61.17      0.788732      0.513472    0.886364
# 5    58.36    0.16   80.77   58.52      0.764085      0.538390    0.897727
# 11   53.35    0.44   82.05   53.79      0.744718      0.550570    0.863636
# 6    54.79    1.57   80.77   56.36      0.732394      0.523185    0.840909
# 15   54.71    1.73   81.41   56.44      0.762324      0.525371    0.875000
# 9    59.39    2.73   80.77   62.12      0.742958      0.533566    0.886364
# 10   54.68    2.79   81.41   57.47      0.769366      0.505729    0.897727
# 3    57.72    2.61   81.41   60.33      0.762324      0.553262    0.909091
# 7    54.84    1.06   80.77   55.90      0.753521      0.516056    0.897727
# 13   56.68    0.25   79.49   56.93      0.730634      0.526103    0.886364
# 4    56.03    1.86   78.85   57.89      0.735915      0.497426    0.875000
# 8    54.89    2.05   78.21   56.95      0.764085      0.538390    0.863636
# 2    54.25    3.32   75.64   57.58      0.741197      0.540469    0.829545
# 0    54.51    0.79   76.28   55.30      0.772887      0.559658    0.875000
# 12   53.92    3.84   78.85   57.77      0.279930      0.516153    0.261364
#
#     ScannerAUC
# 1     0.647679
# 14    0.690577
# 5     0.746132
# 11    0.628692
# 6     0.665260
# 15    0.635021
# 9     0.641350
# 10    0.647679
# 3     0.752461
# 7     0.647679
# 13    0.690577
# 4     0.831927
# 8     0.677918
# 2     0.658931
# 0     0.635021
# 12    0.588608

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 6           2           2         2           4      0.5         10.0
# 0           2           2         2           4      0.5          0.1
# 5           2           2         2           4      0.5          1.0
# 7           2           2         2           4      0.5         10.0
# 8           2           2         2           4      0.5         10.0
# 2           2           2         2           4      0.5          0.1
# 1           2           2         2           4      0.5          0.1
# 4           2           2         2           4      0.5          1.0
# 3           2           2         2           4      0.5          1.0
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 6             0.1   81.73    0.32   59.15    3.28   82.05   62.44
# 0             0.1   81.09    0.32   56.26    1.70   81.41   57.95
# 5            10.0   80.77    3.21   62.36    3.46   83.97   65.82
# 7             1.0   79.49    1.28   60.53    8.60   80.77   69.13
# 8            10.0   79.49    2.56   56.69    0.44   82.05   57.13
# 2            10.0   78.53    0.32   58.91    1.88   78.85   60.80
# 1             1.0   78.21    1.28   55.69    3.42   79.49   59.10
# 4             1.0   76.28    1.28   58.13    3.96   77.56   62.10
# 3             0.1   75.64    1.28   55.14    2.87   76.92   58.01
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 6      0.739437      0.571278    0.920455    0.758790
# 0      0.774648      0.520880    0.875000    0.684248
# 5      0.758803      0.567067    0.897727    0.746132
# 7      0.698944      0.530820    0.863636    0.677918
# 8      0.742958      0.529582    0.875000    0.684248
# 2      0.735915      0.545239    0.840909    0.714487
# 1      0.725352      0.518921    0.806818    0.646273
# 4      0.748239      0.556686    0.829545    0.708158
# 3      0.758803      0.586989    0.840909    0.616034

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 8           3           3         4           2      0.5         10.0
# 3           3           3         4           2      0.5          1.0
# 6           3           3         4           2      0.5         10.0
# 0           3           3         4           2      0.5          0.1
# 1           3           3         4           2      0.5          0.1
# 5           3           3         4           2      0.5          1.0
# 7           3           3         4           2      0.5         10.0
# 2           3           3         4           2      0.5          0.1
# 4           3           3         4           2      0.5          1.0
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 8            10.0   81.41    1.92   56.75    0.64   83.33   57.39
# 3             0.1   80.45    2.88   57.44    3.17   83.33   60.61
# 6             0.1   80.13    0.64   52.05    0.41   80.77   52.46
# 0             0.1   79.81    0.96   55.29    3.04   80.77   58.33
# 1             1.0   78.21    0.00   59.78    6.51   78.21   66.29
# 5            10.0   76.60    4.17   55.77    5.02   80.77   60.80
# 7             1.0   74.04    0.32   53.21    0.39   74.36   53.60
# 2            10.0   54.49   26.92   54.78    2.32   81.41   57.09
# 4             1.0   50.64   24.36   57.13    5.75   75.00   62.88
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 8      0.755282      0.537044    0.875000    0.782700
# 3      0.737676      0.510446    0.886364    0.690577
# 6      0.732394      0.491310    0.897727    0.696906
# 0      0.767606      0.548491    0.897727    0.647679
# 1      0.764085      0.574250    0.863636    0.727145
# 5      0.750000      0.549784    0.818182    0.652602
# 7      0.436620      0.543301    0.556818    0.605485
# 2      0.751761      0.507021    0.875000    0.635021
# 4      0.234155      0.520310    0.181818    0.544304

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 6           2           3         2           4      0.5         10.0
# 0           2           3         2           4      0.5          0.1
# 8           2           3         2           4      0.5         10.0
# 1           2           3         2           4      0.5          0.1
# 4           2           3         2           4      0.5          1.0
# 7           2           3         2           4      0.5         10.0
# 2           2           3         2           4      0.5          0.1
# 3           2           3         2           4      0.5          1.0
# 5           2           3         2           4      0.5          1.0
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 6             0.1   80.77    0.64   54.46    2.19   81.41   56.65
# 0             0.1   79.81    2.24   56.64    4.91   82.05   61.55
# 8            10.0   79.81    1.60   58.64    1.63   81.41   60.26
# 1             1.0   79.17    0.32   58.68    3.25   79.49   61.93
# 4             1.0   79.17    0.32   55.22    0.65   79.49   55.87
# 7             1.0   78.85    0.00   54.80    2.52   78.85   57.32
# 2            10.0   77.24    2.24   56.74    0.68   79.49   57.42
# 3             0.1   76.92    4.49   58.93    0.92   81.41   59.85
# 5            10.0   74.68    0.96   55.83    2.98   75.64   58.81
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 6      0.771127      0.562577    0.897727    0.696906
# 0      0.734155      0.488391    0.863636    0.677918
# 8      0.741197      0.548437    0.829545    0.609705
# 1      0.765845      0.611176    0.818182    0.701828
# 4      0.750000      0.557752    0.840909    0.665260
# 7      0.769366      0.549557    0.886364    0.690577
# 2      0.713028      0.543333    0.772727    0.578059
# 3      0.757042      0.546079    0.840909    0.665260
# 5      0.716549      0.557419    0.829545    0.708158

# %% [markdown]
# # GCN with VAE comparison Norm

# %%
# GNN with one layer masking and Frobenius norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 7           2           2         2           4      0.5         10.0
# 8           2           2         2           4      0.5         10.0
# 2           2           2         2           4      0.5          0.1
# 1           2           2         2           4      0.5          0.1
# 3           2           2         2           4      0.5          1.0
# 5           2           2         2           4      0.5          1.0
# 4           2           2         2           4      0.5          1.0
# 6           2           2         2           4      0.5         10.0
# 0           2           2         2           4      0.5          0.1
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 7             1.0   82.91    0.63   58.67    0.07   83.54   58.74
# 8            10.0   82.59    3.48   60.96    4.25   86.08   65.21
# 2            10.0   82.28    1.90   57.74    1.41   84.18   59.14
# 1             1.0   79.43    0.32   59.71    2.98   79.75   62.69
# 3             0.1   79.43    1.58   55.60    4.10   81.01   59.70
# 5            10.0   79.43    4.75   55.07    0.60   84.18   55.67
# 4             1.0   78.48    1.27   56.33    3.31   79.75   59.64
# 6             0.1   78.48    1.27   57.90    3.05   79.75   60.95
# 0             0.1   77.22    1.90   54.79    2.18   79.11   56.97
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 7      0.702465      0.548890    0.844444     0.73750
# 8      0.174296      0.500000    0.111111     0.50000
# 2      0.174296      0.500000    0.111111     0.50000
# 1      0.755282      0.556966    0.833333     0.64375
# 3      0.735915      0.529302    0.833333     0.68750
# 5      0.174296      0.500000    0.111111     0.50000
# 4      0.779930      0.544001    0.933333     0.83125
# 6      0.755282      0.564935    0.888889     0.71875
# 0      0.735915      0.537270    0.833333     0.64375

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights_l1.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 0               1   80.38     1.9   57.81    0.99   82.28    58.8
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 0      0.176056      0.501066    0.111111         0.5

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights_l2.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 0               1    78.8    0.32   57.28    3.54   79.11   60.82
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 0      0.725352      0.546811    0.822222      0.6375

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights_elastic.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 7           2           2         2           4      0.5           10
# 2           2           2         2           4      0.5           10
# 4           2           2         2           4      0.5           10
# 6           2           2         2           4      0.5           10
# 8           2           2         2           4      0.5           10
# 5           2           2         2           4      0.5           10
# 0           2           2         2           4      0.5           10
# 1           2           2         2           4      0.5           10
# 3           2           2         2           4      0.5           10
#
#    weights_lambda  weights_elastic  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  \
# 7            10.0              0.5   83.86    0.95   58.39    0.95   84.81
# 2             0.1              1.0   82.91    1.27   59.40    1.00   84.18
# 4             1.0              0.5   82.28    0.63   53.36    0.34   82.91
# 6            10.0              0.2   80.70    0.32   59.34    1.98   81.01
# 8            10.0              1.0   80.38    0.63   61.15    4.80   81.01
# 5             1.0              1.0   79.75    0.63   55.49    0.27   80.38
# 0             0.1              0.2   79.11    0.63   59.09    1.42   79.75
# 1             0.1              0.5   79.11    1.27   57.55    1.19   80.38
# 3             1.0              0.2   78.48    1.90   55.80    1.39   80.38
#
#    MaxAUC  TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 7   59.34      0.174296      0.500000    0.111111     0.50000
# 2   60.40      0.422535      0.570632    0.466667     0.65625
# 4   53.70      0.174296      0.500000    0.111111     0.50000
# 6   61.32      0.174296      0.500000    0.111111     0.50000
# 8   65.95      0.174296      0.500000    0.111111     0.50000
# 5   55.76      0.174296      0.500000    0.111111     0.50000
# 0   60.51      0.667254      0.559443    0.722222     0.62500
# 1   58.74      0.700704      0.563761    0.822222     0.63750
# 3   57.18      0.174296      0.500000    0.111111     0.50000

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights_force_0_1.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda']
additional_columns = ['AvgAcc', 'StdAcc', 'AvgAUC', 'StdAUC', 'MaxAcc', 'MaxAUC', 'TreatmentAcc', 'TreatmentAUC', 'ScannerAcc', 'ScannerAUC']
columns.extend(additional_columns)
df_gcn = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df_gcn.sort_values(by='AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  AvgAcc  StdAcc  AvgAUC  StdAUC  MaxAcc  MaxAUC  \
# 0               1   78.16    1.58   54.64    0.68   79.75   55.32
#
#    TreatmentAcc  TreatmentAUC  ScannerAcc  ScannerAUC
# 0      0.739437      0.559325    0.866667      0.6625

# %% [markdown]
# # GCN VAE NULLING OUT

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_vae_weights_elastic_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_TreatmentAcc', 'Perc0_TreatmentAUC', 'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_TreatmentAcc', 'Perc07_TreatmentAUC', 'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_TreatmentAcc', 'Perc08_TreatmentAUC', 'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_TreatmentAcc', 'Perc095_TreatmentAUC', 'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_TreatmentAcc', 'Perc09_TreatmentAUC', 'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df
# Out:
# 50
# 50
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10              0.5         80.06          2.85  ...
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_TreatmentAcc  \
# 0           0.888889                0.5              0.826011
#
#    Perc095_TreatmentAUC  Perc095_ScannerAcc  Perc095_ScannerAUC  \
# 0                   0.5            0.888889                 0.5
#
#    Perc09_TreatmentAcc  Perc09_TreatmentAUC  Perc09_ScannerAcc  \
# 0             0.826011                  0.5           0.888889
#
#    Perc09_ScannerAUC
# 0                0.5
#
# [1 rows x 50 columns]

# %%
df[['Perc0_AvgAcc', 'Perc07_AvgAcc', 'Perc08_AvgAcc', 'Perc095_AvgAcc', 'Perc09_AvgAcc']]
# Out:
#    Perc0_AvgAcc  Perc07_AvgAcc  Perc08_AvgAcc  Perc095_AvgAcc  Perc09_AvgAcc
# 0         80.06          85.76          85.13           85.44          85.13

# %%
df[['Perc0_TreatmentAcc', 'Perc07_TreatmentAcc', 'Perc08_TreatmentAcc', 'Perc095_TreatmentAcc', 'Perc09_TreatmentAcc']]
# Out:
#    Perc0_TreatmentAcc  Perc07_TreatmentAcc  Perc08_TreatmentAcc  \
# 0             0.71529             0.824253             0.826011
#
#    Perc095_TreatmentAcc  Perc09_TreatmentAcc
# 0              0.826011             0.826011

# %%
df[['Perc0_ScannerAcc', 'Perc07_ScannerAcc', 'Perc08_ScannerAcc', 'Perc095_ScannerAcc', 'Perc09_ScannerAcc']]
# Out:
#    Perc0_ScannerAcc  Perc07_ScannerAcc  Perc08_ScannerAcc  Perc095_ScannerAcc  \
# 0          0.877778           0.888889           0.888889            0.888889
#
#    Perc09_ScannerAcc
# 0           0.888889

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_mae_frobenius_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_TreatmentAcc', 'Perc0_TreatmentAUC', 'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_TreatmentAcc', 'Perc07_TreatmentAUC', 'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_TreatmentAcc', 'Perc08_TreatmentAUC', 'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_TreatmentAcc', 'Perc095_TreatmentAUC', 'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_TreatmentAcc', 'Perc09_TreatmentAUC', 'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df
# Out:
# 50
# 50
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10              0.5         81.01          0.63  ...
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_TreatmentAcc  \
# 0           0.877778             0.5375              0.826011
#
#    Perc095_TreatmentAUC  Perc095_ScannerAcc  Perc095_ScannerAUC  \
# 0              0.503987            0.888889                 0.5
#
#    Perc09_TreatmentAcc  Perc09_TreatmentAUC  Perc09_ScannerAcc  \
# 0             0.817223             0.494681           0.888889
#
#    Perc09_ScannerAUC
# 0                0.5
#
# [1 rows x 50 columns]

# %%
df[['Perc0_AvgAcc', 'Perc07_AvgAcc', 'Perc08_AvgAcc', 'Perc095_AvgAcc', 'Perc09_AvgAcc']]
# Out:
#    Perc0_AvgAcc  Perc07_AvgAcc  Perc08_AvgAcc  Perc095_AvgAcc  Perc09_AvgAcc
# 0         81.01          81.33          81.01           81.96          79.43

# %%
df[['Perc0_TreatmentAcc', 'Perc07_TreatmentAcc', 'Perc08_TreatmentAcc', 'Perc095_TreatmentAcc', 'Perc09_TreatmentAcc']]
# Out:
#    Perc0_TreatmentAcc  Perc07_TreatmentAcc  Perc08_TreatmentAcc  \
# 0            0.776801             0.822496             0.824253
#
#    Perc095_TreatmentAcc  Perc09_TreatmentAcc
# 0              0.826011             0.817223

# %%
df[['Perc0_ScannerAcc', 'Perc07_ScannerAcc', 'Perc08_ScannerAcc', 'Perc095_ScannerAcc', 'Perc09_ScannerAcc']]
# Out:
#    Perc0_ScannerAcc  Perc07_ScannerAcc  Perc08_ScannerAcc  Perc095_ScannerAcc  \
# 0          0.922222           0.877778           0.877778            0.888889
#
#    Perc09_ScannerAcc
# 0           0.888889

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT/save_results_tuning_gcn_baseline_masking_frobenius_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_TreatmentAcc', 'Perc0_TreatmentAUC', 'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_TreatmentAcc', 'Perc07_TreatmentAUC', 'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_TreatmentAcc', 'Perc08_TreatmentAUC', 'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_TreatmentAcc', 'Perc095_TreatmentAUC', 'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_TreatmentAcc', 'Perc09_TreatmentAUC', 'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df
# Out:
# 50
# 50
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10              0.5         78.16          1.58  ...
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_TreatmentAcc  \
# 0           0.855556              0.525              0.804921
#
#    Perc095_TreatmentAUC  Perc095_ScannerAcc  Perc095_ScannerAUC  \
# 0              0.503181            0.833333             0.46875
#
#    Perc09_TreatmentAcc  Perc09_TreatmentAUC  Perc09_ScannerAcc  \
# 0             0.811951             0.507436           0.866667
#
#    Perc09_ScannerAUC
# 0              0.575
#
# [1 rows x 50 columns]

# %%
df[['Perc0_AvgAcc', 'Perc07_AvgAcc', 'Perc08_AvgAcc', 'Perc095_AvgAcc', 'Perc09_AvgAcc']]
# Out:
#    Perc0_AvgAcc  Perc07_AvgAcc  Perc08_AvgAcc  Perc095_AvgAcc  Perc09_AvgAcc
# 0         78.16          82.91          83.86           83.86          83.86

# %%
df[['Perc0_TreatmentAcc', 'Perc07_TreatmentAcc', 'Perc08_TreatmentAcc', 'Perc095_TreatmentAcc', 'Perc09_TreatmentAcc']]
# Out:
#    Perc0_TreatmentAcc  Perc07_TreatmentAcc  Perc08_TreatmentAcc  \
# 0            0.764499             0.804921             0.808436
#
#    Perc095_TreatmentAcc  Perc09_TreatmentAcc
# 0              0.804921             0.811951

# %%
df[['Perc0_ScannerAcc', 'Perc07_ScannerAcc', 'Perc08_ScannerAcc', 'Perc095_ScannerAcc', 'Perc09_ScannerAcc']]
# Out:
#    Perc0_ScannerAcc  Perc07_ScannerAcc  Perc08_ScannerAcc  Perc095_ScannerAcc  \
# 0          0.888889           0.866667           0.855556            0.833333
#
#    Perc09_ScannerAcc
# 0           0.866667

# %% [markdown]
# # SpaRef Pipeline: GCN

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT_sparef/save_results_tuning_sparef_gcn_baseline_masking_mae_weights_frobenius_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5            1
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0            0.01              0.5         75.45          1.41  ...
#
#    Perc0_ScannerAcc  Perc0_ScannerAUC  Perc07_ScannerAcc  Perc07_ScannerAUC  \
# 0          0.854015           0.69249           0.875912           0.668775
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_ScannerAcc  \
# 0           0.832117           0.587549            0.832117
#
#    Perc095_ScannerAUC  Perc09_ScannerAcc  Perc09_ScannerAUC
# 0            0.495652           0.846715           0.559486
#
# [1 rows x 40 columns]

# %%
df[['Perc0_AvgAcc', 'Perc07_AvgAcc', 'Perc08_AvgAcc', 'Perc095_AvgAcc', 'Perc09_AvgAcc']]
# Out:
#    Perc0_AvgAcc  Perc07_AvgAcc  Perc08_AvgAcc  Perc095_AvgAcc  Perc09_AvgAcc
# 0         75.45          79.72           81.1           83.31          82.35

# %%
df[['Perc0_ScannerAcc', 'Perc07_ScannerAcc', 'Perc08_ScannerAcc', 'Perc095_ScannerAcc', 'Perc09_ScannerAcc']]
# Out:
#    Perc0_ScannerAcc  Perc07_ScannerAcc  Perc08_ScannerAcc  Perc095_ScannerAcc  \
# 0          0.854015           0.875912           0.832117            0.832117
#
#    Perc09_ScannerAcc
# 0           0.846715

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT_sparef/save_results_tuning_sparef_gcn_baseline_masking_vae_weights_elastic_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df.sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#     MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 7            2           2         2           4      0.5          0.1
# 21           2           2         2           4      0.5         10.0
# 12           2           2         2           4      0.5          1.0
# 13           2           2         2           4      0.5          1.0
# 3            2           2         2           4      0.5          0.1
# 16           2           2         2           4      0.5          1.0
# 10           2           2         2           4      0.5          1.0
# 22           2           2         2           4      0.5         10.0
# 1            2           2         2           4      0.5          0.1
# 6            2           2         2           4      0.5          0.1
# 19           2           2         2           4      0.5         10.0
# 5            2           2         2           4      0.5          0.1
# 8            2           2         2           4      0.5          0.1
# 20           2           2         2           4      0.5         10.0
# 24           2           2         2           4      0.5         10.0
# 9            2           2         2           4      0.5          1.0
# 14           2           2         2           4      0.5          1.0
# 25           2           2         2           4      0.5         10.0
# 17           2           2         2           4      0.5          1.0
# 0            2           2         2           4      0.5          0.1
# 18           2           2         2           4      0.5         10.0
# 26           2           2         2           4      0.5         10.0
# 2            2           2         2           4      0.5          0.1
# 4            2           2         2           4      0.5          0.1
# 11           2           2         2           4      0.5          1.0
# 23           2           2         2           4      0.5         10.0
# 15           2           2         2           4      0.5          1.0
#
#     weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 7             10.0              1.0         84.18          0.63  ...
# 21             1.0              0.1         83.86          0.95  ...
# 12             1.0              0.1         83.54          1.90  ...
# 13             1.0              1.0         82.91          2.53  ...
# 3              1.0              0.1         82.91          0.63  ...
# 16            10.0              1.0         82.59          0.32  ...
# 10             0.1              1.0         82.59          0.32  ...
# 22             1.0              1.0         81.96          1.58  ...
# 1              0.1              1.0         81.33          1.58  ...
# 6             10.0              0.1         81.33          0.32  ...
# 19             0.1              1.0         81.33          1.58  ...
# 5              1.0             10.0         81.01          1.27  ...
# 8             10.0             10.0         81.01          1.27  ...
# 20             0.1             10.0         80.70          0.95  ...
# 24            10.0              0.1         80.38          5.06  ...
# 9              0.1              0.1         80.38          1.90  ...
# 14             1.0             10.0         79.75          1.90  ...
# 25            10.0              1.0         79.75          0.63  ...
# 17            10.0             10.0         79.75          3.80  ...
# 0              0.1              0.1         79.43          0.32  ...
# 18             0.1              0.1         79.43          0.95  ...
# 26            10.0             10.0         79.43          0.95  ...
# 2              0.1             10.0         78.80          0.95  ...
# 4              1.0              1.0         78.48          1.90  ...
# 11             0.1             10.0         78.16          0.95  ...
# 23             1.0             10.0         77.22          2.53  ...
# 15            10.0              0.1         74.37          3.48  ...
#
# 18          0.733333           0.500000           0.500000
# 0           0.700000           0.544444           0.544444
# 5           0.577778           0.888889           0.888889
# 12          0.111111           0.111111           0.111111
# 15          0.111111           0.111111           0.111111
# 16          0.111111           0.111111           0.111111
# 7           0.111111           0.111111           0.111111
# 6           0.111111           0.111111           0.111111
# 4           0.111111           0.111111           0.111111
# 21          0.111111           0.111111           0.111111
# 22          0.111111           0.111111           0.111111
# 3           0.111111           0.111111           0.111111
# 24          0.111111           0.111111           0.111111
# 25          0.111111           0.111111           0.111111
# 13          0.111111           0.111111           0.111111
#
#     Perc095_ScannerAcc  Perc09_ScannerAcc
# 26            0.888889           0.888889
# 9             0.488889           0.488889
# 14            0.888889           0.888889
# 1             0.111111           0.111111
# 11            0.888889           0.888889
# 2             0.888889           0.888889
# 19            0.111111           0.111111
# 8             0.888889           0.888889
# 23            0.888889           0.888889
# 17            0.888889           0.888889
# 20            0.888889           0.888889
# 10            0.111111           0.111111
# 18            0.500000           0.500000
# 0             0.544444           0.544444
# 5             0.888889           0.888889
# 12            0.111111           0.111111
# 15            0.111111           0.111111
# 16            0.111111           0.111111
# 7             0.111111           0.111111
# 6             0.111111           0.111111
# 4             0.111111           0.111111
# 21            0.111111           0.111111
# 22            0.111111           0.111111
# 3             0.111111           0.111111
# 24            0.111111           0.111111
# 25            0.111111           0.111111
# 13            0.111111           0.111111

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT_sparef/save_results_tuning_sparef_gcn_baseline_masking_mae_weights_elastic_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df.sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5          0.1
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10                1         81.95          1.95  ...
#
#    Perc0_ScannerAcc  Perc0_ScannerAUC  Perc07_ScannerAcc  Perc07_ScannerAUC  \
# 0          0.862745          0.710227           0.862745                0.5
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_ScannerAcc  \
# 0           0.862745                0.5            0.862745
#
#    Perc095_ScannerAUC  Perc09_ScannerAcc  Perc09_ScannerAUC
# 0                 0.5           0.862745                0.5
#
# [1 rows x 40 columns]

# %%
df[['Perc0_AvgAcc', 'Perc07_AvgAcc', 'Perc08_AvgAcc', 'Perc095_AvgAcc', 'Perc09_AvgAcc']].sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#    Perc0_AvgAcc  Perc07_AvgAcc  Perc08_AvgAcc  Perc095_AvgAcc  Perc09_AvgAcc
# 0         81.95          85.62          86.29           85.95          85.95

# %%
df[['Perc0_ScannerAcc', 'Perc07_ScannerAcc', 'Perc08_ScannerAcc', 'Perc095_ScannerAcc', 'Perc09_ScannerAcc']].sort_values(by='Perc0_ScannerAcc', ascending=False)
# Out:
#    Perc0_ScannerAcc  Perc07_ScannerAcc  Perc08_ScannerAcc  Perc095_ScannerAcc  \
# 0          0.862745           0.862745           0.862745            0.862745
#
#    Perc09_ScannerAcc
# 0           0.862745

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT_sparef/save_results_tuning_gcn_baseline_masking_mae_weights_elastic_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df.sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5          0.1
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10                1         82.07          2.27  ...
#
#    Perc0_ScannerAcc  Perc0_ScannerAUC  Perc07_ScannerAcc  Perc07_ScannerAUC  \
# 0          0.833333          0.428571           0.916667           0.471429
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_ScannerAcc  \
# 0           0.888889           0.457143            0.916667
#
#    Perc095_ScannerAUC  Perc09_ScannerAcc  Perc09_ScannerAUC
# 0            0.471429           0.888889           0.457143
#
# [1 rows x 40 columns]

# %%
df[["Perc0_AvgAcc", "Perc0_ScannerAcc"]]
# Out:
#    Perc0_AvgAcc  Perc0_ScannerAcc
# 0         82.07          0.833333

# %%
df[['Perc0_AvgAcc', 'Perc07_AvgAcc', 'Perc08_AvgAcc', 'Perc095_AvgAcc', 'Perc09_AvgAcc']].sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#    Perc0_AvgAcc  Perc07_AvgAcc  Perc08_AvgAcc  Perc095_AvgAcc  Perc09_AvgAcc
# 0          90.6           89.2          91.07           89.19           90.6

# %%
df[['Perc0_ScannerAcc', 'Perc07_ScannerAcc', 'Perc08_ScannerAcc', 'Perc095_ScannerAcc', 'Perc09_ScannerAcc']].sort_values(by='Perc0_ScannerAcc', ascending=False)
# Out:
#    Perc0_ScannerAcc  Perc07_ScannerAcc  Perc08_ScannerAcc  Perc095_ScannerAcc  \
# 0          0.833333           0.823529           0.843137            0.833333
#
#    Perc09_ScannerAcc
# 0           0.823529

# %% [markdown]
# # 1024

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT_1024/save_results_tuning_1024_sparef_gcn_baseline_masking_mae_weights_elastic_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0']:
            value = value.replace(perc, "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_TreatmentAcc', 'Perc0_TreatmentAUC', 'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_TreatmentAcc', 'Perc07_TreatmentAUC', 'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_TreatmentAcc', 'Perc08_TreatmentAUC', 'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_TreatmentAcc', 'Perc095_TreatmentAUC', 'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_TreatmentAcc', 'Perc09_TreatmentAUC', 'Perc09_ScannerAcc', 'Perc09_ScannerAUC']
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df.sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10              0.5         82.95          0.95  ...
#
#    Perc08_ScannerAcc  Perc08_ScannerAUC  Perc095_TreatmentAcc  \
# 0           0.911765           0.798701              0.817223
#
#    Perc095_TreatmentAUC  Perc095_ScannerAcc  Perc095_ScannerAUC  \
# 0              0.508148            0.852941            0.554383
#
#    Perc09_TreatmentAcc  Perc09_TreatmentAUC  Perc09_ScannerAcc  \
# 0             0.801406             0.494483           0.901961
#
#    Perc09_ScannerAUC
# 0           0.732955
#
# [1 rows x 50 columns]

# %%
df[["Perc0_AvgAcc", "Perc0_ScannerAcc"]]
# Out:
#    Perc0_AvgAcc  Perc0_ScannerAcc
# 0         82.95          0.852941

# %%
# GNN with one layer masking and L1 norm regularization
with open('./modified_XGW-GAT_1024/save_results_tuning_1024_gcn_baseline_masking_vae_weights_elastic_nullingout.pkl', 'rb') as f:
    results = pkl.load(f)

# Function to extract numbers from a string
def extract_numbers(s):
    return [float(n) for n in re.findall(r"[-+]?\d*\.\d+|\d+", s)]

# Process the data
formatted_data = []
for key, values in results.items():
    row = list(key)
    for value in values:
        for perc in ['perc 0.7', 'perc 0.8', 'perc 0.95', 'perc 0.9', 'perc 0' ]:
            value = value.replace(perc, "")
        # get rid of combinations from 0 to 4 of (0, 1), ...
        for i in range(5):
            for j in range(5):
                value = value.replace(f"({i}, {j})", "")
        numbers = extract_numbers(value)
        row.extend(numbers)
    formatted_data.append(row)

# Creating DataFrame with appropriate column names
columns = ['MLP_layers', 'GNN_layers', 'num_head', 'hidden_dim', 'dropout', 'loss_lambda', 'weights_lambda', 'weights_elastic']
additional_columns = ['Perc0_AvgAcc', 'Perc0_StdAcc', 'Perc0_AvgAUC', 'Perc0_StdAUC',
                      'Perc07_AvgAcc', 'Perc07_StdAcc', 'Perc07_AvgAUC', 'Perc07_StdAUC',
                      'Perc08_AvgAcc', 'Perc08_StdAcc', 'Perc08_AvgAUC', 'Perc08_StdAUC',
                      'Perc095_AvgAcc', 'Perc095_StdAcc', 'Perc095_AvgAUC', 'Perc095_StdAUC',
                      'Perc09_AvgAcc', 'Perc09_StdAcc', 'Perc09_AvgAUC', 'Perc09_StdAUC',
                      'MaxAvgAcc', 'MaxAvgAUC',
                      'Perc0_TreatmentAcc', 'Perc0_TreatmentAUC', 'Perc0_ScannerAcc', 'Perc0_ScannerAUC',
                      'Perc07_TreatmentAcc', 'Perc07_TreatmentAUC', 'Perc07_ScannerAcc', 'Perc07_ScannerAUC',
                      'Perc08_TreatmentAcc', 'Perc08_TreatmentAUC', 'Perc08_ScannerAcc', 'Perc08_ScannerAUC',
                      'Perc095_TreatmentAcc', 'Perc095_TreatmentAUC', 'Perc095_ScannerAcc', 'Perc095_ScannerAUC',
                      'Perc09_TreatmentAcc', 'Perc09_TreatmentAUC', 'Perc09_ScannerAcc', 'Perc09_ScannerAUC',
                      "Sim_Masks_0,1", "Sim_Masks_0,2", "Sim_Masks_0,3", "Sim_Masks_0,4",
                      "Sim_Masks_1,0", "Sim_Masks_1,2", "Sim_Masks_1,3", "Sim_Masks_1,4",
                      "Sim_Masks_2,0", "Sim_Masks_2,1", "Sim_Masks_2,3", "Sim_Masks_2,4",
                      "Sim_Masks_3,0", "Sim_Masks_3,1", "Sim_Masks_3,2", "Sim_Masks_3,4",
                      "Sim_Masks_4,0", "Sim_Masks_4,1", "Sim_Masks_4,2", "Sim_Masks_4,3"]
columns.extend(additional_columns)
df = pd.DataFrame(formatted_data, columns=columns)

# Display the DataFrame
df.sort_values(by='Perc0_AvgAcc', ascending=False)
# Out:
#    MLP_layers  GNN_layers  num_head  hidden_dim  dropout  loss_lambda  \
# 0           2           2         2           4      0.5           10
#
#    weights_lambda  weights_elastic  Perc0_AvgAcc  Perc0_StdAcc  ...  \
# 0              10              0.5         83.29          2.04  ...
#
#    Sim_Masks_2,3  Sim_Masks_2,4  Sim_Masks_3,0  Sim_Masks_3,1  Sim_Masks_3,2  \
# 0         0.3061          0.375         0.3061         0.3061         0.3061
#
#    Sim_Masks_3,4  Sim_Masks_4,0  Sim_Masks_4,1  Sim_Masks_4,2  Sim_Masks_4,3
# 0         0.5644          0.375          0.375          0.375         0.5644
#
# [1 rows x 70 columns]

# %%
df[["Perc0_AvgAcc", "Perc0_ScannerAcc"]]
# Out:
#    Perc0_AvgAcc  Perc0_ScannerAcc
# 0         83.29          0.960784

# %%
df[["Sim_Masks_0,1", "Sim_Masks_0,2", "Sim_Masks_0,3", "Sim_Masks_0,4",
                      "Sim_Masks_1,0", "Sim_Masks_1,2", "Sim_Masks_1,3", "Sim_Masks_1,4",
                      "Sim_Masks_2,0", "Sim_Masks_2,1", "Sim_Masks_2,3", "Sim_Masks_2,4",
                      "Sim_Masks_3,0", "Sim_Masks_3,1", "Sim_Masks_3,2", "Sim_Masks_3,4",
                      "Sim_Masks_4,0", "Sim_Masks_4,1", "Sim_Masks_4,2", "Sim_Masks_4,3"]]
# Out:
#    Sim_Masks_0,1  Sim_Masks_0,2  Sim_Masks_0,3  Sim_Masks_0,4  Sim_Masks_1,0  \
# 0            1.0            1.0         0.3061          0.375            1.0
#
#    Sim_Masks_1,2  Sim_Masks_1,3  Sim_Masks_1,4  Sim_Masks_2,0  Sim_Masks_2,1  \
# 0            1.0         0.3061          0.375            1.0            1.0
#
#    Sim_Masks_2,3  Sim_Masks_2,4  Sim_Masks_3,0  Sim_Masks_3,1  Sim_Masks_3,2  \
# 0         0.3061          0.375         0.3061         0.3061         0.3061
#
#    Sim_Masks_3,4  Sim_Masks_4,0  Sim_Masks_4,1  Sim_Masks_4,2  Sim_Masks_4,3
# 0         0.5644          0.375          0.375          0.375         0.5644

# %%
np.mean(formatted_data[0][-20:])
# Out:
# 0.56077
